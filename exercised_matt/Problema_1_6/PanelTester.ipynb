# %% [markdown]
# El objetivo de este informe es responder al problema propuesto 1.6. <br/>
# Debemos probar diferentes parametros para los paneles y pintar la reflexion y transmision

# %%
import numpy as np 
import matplotlib.pyplot as plt
from Problema_1_6 import PyPanel

# %%
panel1 = PyPanel(epsilon_r = 5.0, d = 100e-6)
plt.plot(PyPanel.omega/2/np.pi,np.abs(panel1.T()))
plt.plot(PyPanel.omega/2/np.pi,np.abs(panel1.R()))
plt.show()

# %%
panel2 = PyPanel(epsilon_r = 5.0, d = 10e-3)
plt.plot(PyPanel.omega/2/np.pi,np.abs(panel2.T()))
plt.plot(PyPanel.omega/2/np.pi,np.abs(panel2.R()))
plt.show()

# %%
panel3 = PyPanel(sigma = 10.0)
plt.plot(PyPanel.omega/2/np.pi,np.abs(panel3.T()))
plt.plot(PyPanel.omega/2/np.pi,np.abs(panel3.R()))
plt.show()

# %%
panel4 = PyPanel(sigma = 10.0, d = 10e-3)
plt.plot(PyPanel.omega/2/np.pi,np.abs(panel4.T()))
plt.plot(PyPanel.omega/2/np.pi,np.abs(panel4.R()))
plt.show()
